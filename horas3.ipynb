# %%
def pagoempleado (horas,pesos):
 pagodeldia= horas*pesos 
 pagodelasemana=pagodeldia*5
 pagodelmes=pagodelasemana*4
 print("El pago del dia es:", pagodeldia)
 print("El pago de la semana es:", pagodelasemana)
 print("El pago del mes es:", pagodelmes)
pesos=150
horas=float (input("Ingresa el numero de horas que trabajo:"))
pagoempleado(horas,pesos)
# Out:
# Ingresa el numero de horas que trabajo:1
# El pago del dia es: 150.0
# El pago de la semana es: 750.0
# El pago del mes es: 3000.0
